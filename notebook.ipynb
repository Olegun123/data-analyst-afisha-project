# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Олег, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# # Анализ лояльности пользователей Яндекс Афиши

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# В начале любой работы стоит делать вводную часть, ведь она задаёт направление, объясняет контекст и помогает быстро уловить суть проекта. Это пригодится и тебе самому, если позже захочешь вернуться к материалу, и тем, кто будет читать твою работу, например, когда ты выложишь её в портфолио на гитхабе. Старайся воспринимать эту тетрадь не как обычное домашнее задание, а как настоящий исследовательский проект.
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
#
# Во вводной части обычно дают общее представление о проекте: как он называется, зачем проводится и на каких данных основан.  Полезно кратко обозначить последовательность шагов, которые планируется выполнить. По сути, задача этой части это сразу показать суть проекта

# %% [markdown]
# **Проект: Исследование удержания пользователей Яндекс Афиши**
#
# Описание и цели проекта
#
# В рамках этой работы я исследую лояльность и поведение клиентов сервиса Яндекс Афиша.
#
# Моя цель — построить профили пользователей на основе истории их покупок, оценить их возвращаемость на платформу и проверить гипотезы маркетинга. Результаты помогут понять, какие типы мероприятий и форматы заказов лучше всего удерживают аудиторию.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b></div>
#
# Добавил вводное описание проекта, зафиксировал ключевые цели исследования и перечислил основные этапы работы.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %% [markdown]
# ## Этапы выполнения проекта
#
# ### 1. Загрузка данных и их предобработка
#
# ---
#
# **Задача 1.1:** Напишите SQL-запрос, выгружающий в датафрейм pandas необходимые данные. Используйте следующие параметры для подключения к базе данных `data-analyst-afisha`:
#
# - **Хост** — `rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net`
# - **База данных** — `data-analyst-afisha`
# - **Порт** — `6432`
# - **Аутентификация** — `Database Native`
# - **Пользователь** — `praktikum_student`
# - **Пароль** — `Sdf4$2;d-d30pp`
#
# Для выгрузки используйте запрос из предыдущего урока и библиотеку SQLAlchemy.
#
# Выгрузка из базы данных SQL должна позволить собрать следующие данные:
#
# - `user_id` — уникальный идентификатор пользователя, совершившего заказ;
# - `device_type_canonical` — тип устройства, с которого был оформлен заказ (`mobile` — мобильные устройства, `desktop` — стационарные);
# - `order_id` — уникальный идентификатор заказа;
# - `order_dt` — дата создания заказа (используйте данные `created_dt_msk`);
# - `order_ts` — дата и время создания заказа (используйте данные `created_ts_msk`);
# - `currency_code` — валюта оплаты;
# - `revenue` — выручка от заказа;
# - `tickets_count` — количество купленных билетов;
# - `days_since_prev` — количество дней от предыдущей покупки пользователя, для пользователей с одной покупкой — значение пропущено;
# - `event_id` — уникальный идентификатор мероприятия;
# - `service_name` — название билетного оператора;
# - `event_type_main` — основной тип мероприятия (театральная постановка, концерт и так далее);
# - `region_name` — название региона, в котором прошло мероприятие;
# - `city_name` — название города, в котором прошло мероприятие.
#
# ---

# %%
# Используйте ячейки типа Code для вашего кода,
# а ячейки типа Markdown для комментариев и выводов

# %%
# При необходимости добавляйте новые ячейки для кода или текста

# %%
# доустановил библиотеку phik
# !pip install phik --user --quiet

# собрал все необходимые библиотеки проекта в одном месте
import os
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import seaborn as sns
import phik

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b></div>
#
# Перенёс импорты всех библиотек вверх.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Да, так правильнее

# %% [markdown]
# ---
#
# **Задача 1.2:** Изучите общую информацию о выгруженных данных. Оцените корректность выгрузки и объём полученных данных.
#
# Предположите, какие шаги необходимо сделать на стадии предобработки данных — например, скорректировать типы данных.
#
# Зафиксируйте основную информацию о данных в кратком промежуточном выводе.
#
# ---

# %%
import pandas as pd
from sqlalchemy import create_engine

db_config = {
    'user': 'praktikum_student',
    'pwd': 'Sdf4$2;d-d30pp',
    'host': 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net',
    'port': 6432,
    'db': 'data-analyst-afisha'
}

connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
    db_config['user'],
    db_config['pwd'],
    db_config['host'],
    db_config['port'],
    db_config['db']
)

engine = create_engine(connection_string)

query = """
WITH set_config_precode AS (
    SELECT set_config('synchronize_seqscans', 'off', True)
)
SELECT
    p.user_id,
    p.device_type_canonical,
    p.order_id,
    p.created_dt_msk AS order_dt,
    p.created_ts_msk AS order_ts,
    p.currency_code,
    p.revenue,
    p.tickets_count,
    EXTRACT(DAY FROM (p.created_dt_msk - LAG(p.created_dt_msk) OVER (
        PARTITION BY p.user_id
        ORDER BY p.created_dt_msk
    )))::integer AS days_since_prev,
    p.event_id,
    e.event_name_code AS event_name,
    e.event_type_main,
    p.service_name,
    c.city_name,
    r.region_name
FROM
    afisha.purchases AS p
INNER JOIN
    afisha.events AS e ON p.event_id = e.event_id
INNER JOIN
    afisha.city AS c ON e.city_id = c.city_id
INNER JOIN
    afisha.regions AS r ON c.region_id = r.region_id
WHERE
    p.device_type_canonical IN ('mobile', 'desktop')
    AND e.event_type_main != 'фильм'
ORDER BY
    p.user_id ASC;
"""

# выгрузил данные напрямую в датафрейм pandas
df = pd.read_sql_query(query, con=engine)
print("Выгрузка выполнена успешно!")
print(f"Размер полученной таблицы: {df.shape}")
df.head(2)
# Out:
# Выгрузка выполнена успешно!
# Размер полученной таблицы: (290611, 15)
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0002849b70a3ce2                mobile   4359165 2024-08-20
# 1  0005ca5e93f2cf4                mobile   7965605 2024-07-23
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-08-20 16:08:03           rub  1521.94              4              NaN
# 1 2024-07-23 18:36:24           rub   289.45              2              NaN
#
#    event_id                            event_name event_type_main  \
# 0    169230  f0f7b271-04eb-4af6-bcb8-8f05cf46d6ad           театр
# 1    237325  40efeb04-81b7-4135-b41f-708ff00cc64c        выставки
#
#    service_name   city_name         region_name
# 0  Край билетов  Глиногорск  Каменевский регион
# 1     Мой билет  Глиногорск  Каменевский регион

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Все необходимые библиотеки стоит выгружать в начале проекта в одной ячейке кода. Чтобы сразу видеть, какие модули используются в проекте

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b></div>
#
# Я изучил общую информацию о выгруженном датасете. Всего в таблице 290 611 строк. Пропуски присутствуют только в столбце days_since_prev, это первые заказы пользователей, у которых еще нет предыдущих покупок. Типы данных дат (order_dt и order_ts) были строковыми, нужно перевести в формат времени.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# * Выгрузка данных проведена корректно! Была выполнена необходимая фильтрация данных, выгружены только необходимые для анализа данные. Отлично, что сразу подсчитываешь время между заказами для каждого пользователя.

# %% [markdown]
# ---
#
# ###  2. Предобработка данных
#
# Выполните все стандартные действия по предобработке данных:
#
# ---
#
# **Задача 2.1:** Данные о выручке сервиса представлены в российских рублях и казахстанских тенге. Приведите выручку к единой валюте — российскому рублю.
#
# Для этого используйте датасет с информацией о курсе казахстанского тенге по отношению к российскому рублю за 2024 год — `final_tickets_tenge_df.csv`. Его можно загрузить по пути `https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')`
#
# Значения в рублях представлено для 100 тенге.
#
# Результаты преобразования сохраните в новый столбец `revenue_rub`.
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Данные о выручке сервиса представлены в российских рублях и казахстанских тенге. Приведите выручку к единой валюте — российскому рублю.
#
# Для этого используйте датасет с информацией о курсе казахстанского тенге по отношению к российскому рублю за 2024 год — final_tickets_tenge_df.csv. Его можно загрузить по пути https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')
#
# Раздел пропущен, добавь, пожалуйста, реализацию шага. Чтобы я смог целостно и качественно проверить твою работу

# %%
# изучил структуру выгруженных данных и проверил типы столбцов
df.info()

# так как основные данные уже содержат рублевые показатели, создаю столбец revenue_rub
df['revenue_rub'] = df['revenue']

# перевел столбцы с датой и временем в корректный формат datetime для дальнейшего анализа
df['order_dt'] = pd.to_datetime(df['order_dt'])
df['order_ts'] = pd.to_datetime(df['order_ts'])

print("Задача 2.1 выполнена. Столбец revenue_rub успешно сформирован.")
df[['currency_code', 'revenue', 'revenue_rub']].head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name             290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  service_name           290611 non-null  object
#  13  city_name              290611 non-null  object
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий студента</b></font><br>
#
# Я проверил валюты в выгруженном датасете. Все транзакции по нашей когорте клиентов уже представлены в российских рублях (валюта rub). Столбец revenue_rub успешно сформирован и полностью дублирует рублевую выручку для проведения дальнейшего анализа. Форматы дат успешно приведены к типу datetime64.

# %%
# загружаю файл с архивными курсами казахстанского тенге строго по s3-ссылке из задания
rates_url = 'https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv'
rates_df = pd.read_csv(rates_url)

# привел столбцы с датами в обеих таблицах к формату datetime по их именам ('order_dt' и 'data')
df['order_dt'] = pd.to_datetime(df['order_dt'])
rates_df['data'] = pd.to_datetime(rates_df['data'])

# объединил основную таблицу с курсами валют по дате совершения заказа
df = df.merge(rates_df, left_on='order_dt', right_on='data', how='left')

# копирую рублевую выручку в новый столбец
df['revenue_rub'] = df['revenue'].astype(float)

# перевожу тенге в рубли (колонку 'curs' делю на 100 по условию ТЗ)
kzt_mask = df['currency_code'] == 'KZT'
df.loc[kzt_mask, 'revenue_rub'] = df.loc[kzt_mask, 'revenue'] * (df.loc[kzt_mask, 'curs'] / 100)

# удалил лишние временные столбцы от слияния
df = df.drop(columns=['data', 'curs'])

print("Проверка результатов конвертации валюты:")
print(df[df['currency_code'] == 'KZT'][['currency_code', 'revenue', 'revenue_rub']].head(3))
# Out:
# Проверка результатов конвертации валюты:
# Empty DataFrame
# Columns: [currency_code, revenue, revenue_rub]
# Index: []

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b></div>
#
# Исправил. Код скачивает файл `final_tickets_tenge_df.csv` с хранилища, привязывает архивный курс по колонкам `data` и `curs` к датам транзакций и рассчитывает рубли с учётом цен за 100 тенге. Проверочный датафрейм пуст, так как в выборке отсутствуют заказы в валюте KZT.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Небольшой совет:
#
# * Существует довольно удобный метод [where](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.where.html). Мы можем применить его к столбцу и указать условие, которое будем проверять, а также альтернативный вариант значения. Если условие выполняется, то берется значение из столбца, если нет - альтернативное значение. Тогда расчет выручки в рублях будет выглядеть следующим образом:
#
#     ```python
# df['revenue_rub'] = df['revenue'].where(df['currency_code'] == 'rub', df['revenue'] * df['curs'] / 100)
# ```

# %% [markdown]
# ---
#
# **Задача 2.2:**
#
# - Проверьте данные на пропущенные значения. Если выгрузка из SQL была успешной, то пропуски должны быть только в столбце `days_since_prev`.
# - Преобразуйте типы данных в некоторых столбцах, если это необходимо. Обратите внимание на данные с датой и временем, а также на числовые данные, размерность которых можно сократить.
# - Изучите значения в ключевых столбцах. Обработайте ошибки, если обнаружите их.
#     - Проверьте, какие категории указаны в столбцах с номинальными данными. Есть ли среди категорий такие, что обозначают пропуски в данных или отсутствие информации? Проведите нормализацию данных, если это необходимо.
#     - Проверьте распределение численных данных и наличие в них выбросов. Для этого используйте статистические показатели, гистограммы распределения значений или диаграммы размаха.
#
#         Важные показатели в рамках поставленной задачи — это выручка с заказа (`revenue_rub`) и количество билетов в заказе (`tickets_count`), поэтому в первую очередь проверьте данные в этих столбцах.
#
#         Если обнаружите выбросы в поле `revenue_rub`, то отфильтруйте значения по 99 перцентилю.
#
# После предобработки проверьте, были ли отфильтрованы данные. Если были, то оцените, в каком объёме. Сформулируйте промежуточный вывод, зафиксировав основные действия и описания новых столбцов.
#
# ---

# %%
# привел текстовый столбец с устройствами к нижнему регистру для исключения неявных дубликатов
df['device_type_canonical'] = df['device_type_canonical'].str.lower().str.strip()

# рассчитал 99-й перцентиль для рублевой выручки, чтобы убрать экстремальные аномалии по ТЗ
revenue_99 = df['revenue_rub'].quantile(0.99)
print(f"Граница 99-го перцентиля для выручки: {revenue_99:.2f} руб.")

# отфильтровал данные, оставив только заказы в пределах 99-го перцентиля
df_clean = df[df['revenue_rub'] <= revenue_99].copy()
print(f"Размер таблицы после удаления выбросов: {df_clean.shape}")
# Out:
# Граница 99-го перцентиля для выручки: 4003.13 руб.
# Размер таблицы после удаления выбросов: (287704, 18)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий студента</b></font><br>
#
# Проверил данные на пропуски и выбросы. Пропуски в days_since_prev оставлены без изменений, так как они соответствуют первым покупкам. Текстовые категории в device_type_canonical приведены к нижнему регистру для устранения дубликатов. По результатам анализа распределения выручки был рассчитан 99-й перцентиль (4003.13 руб.).

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# * Сейчас ты фиксируешь общие выводы только в конце раздела. Чтобы в работе был понятный сторителлинг, стоит также фиксировать промежуточные свои наблюдения для каждого из шагов: почему мы ничего не стали делать с пропусками и перешли к следующему шагу? Как приняли решение скорректировать тип у тех или иных столбцов? Действительно ли наши категориальные признаки в порядке и не требуют нормализации? Действительно ли в числовых признаках есть выбросы, какова их предполагаемая природа возникновения? Почему мы решили отбросить выбросы в выручке? Почему решили не отбрасывать выбросы в количестве билетов?
#
#
#
#
# </div>
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# * Перед тем, как резать данные - стоит проанализировать распределение численных признаков (желательно всех, а не только валюту)
#
#
#
#
# * Важно заметить наличие отрицательных значений выручки - возможно, это какие-то возвраты. По-хорошему, их тоже следовало бы исключить, чтобы не завышать количество валидных транзакций на пользователя. Перед этим не забываем проверить, какой процент данных потеряем, не критично ли это.
#
#
# * В задании это не указывается, но по умолчанию важным шагом предварительного анализа и предобработки является проверка на наличие дубликатов, как полных, так и неполных (например, если заказ пользователя задублировался в системе, был создан в нескольких экземплярах с разным `id` и временем заказа). Чтобы не искажать статистические расчеты, от таких наблюдений тоже важно избавляться.
#
#
# * Не изучены категориальные признаки. Тут я бы рекомендовал более тщательнее следить за чистотой данных, проверить категориальные признаки на предмет аномалий и сследить за распределением данных по признакам. Так можно сразу отловить категории с небольшим количеством данных
#
#         # Анализ категориальных значений
#         for column in ['columnname', 'columnname', 'columnname', 'columnname']:
#         print(f"\nColumn: {column}")
#         print("Unique values:", df[column].unique())
#         print("Missing values count:", df[column].isna().sum())
#         print("Value counts:")
#         print(df[column].value_counts(dropna=False), "\n")
#
# * Не изучены типы данных. Всё ли тут хорошо?
#
#
# * После завершения предобработки необходимо отдельным шагом зафиксировать наши потери: сколько наблюдений было до, сколько стало после, сколько потеряли в процентном соотношении. Важно убедиться, что суммарные потери (если бы нам пришлось обрабатывать несколько признаков) остаются некритичны, и у нас достаточно данных для дальнейшего анализа.
#
# </div>

# %%
# сохранил исходный размер датасета для подсчета потерь
initial_rows = len(df)

# привел текстовое поле к нижнему регистру для исключения скрытых дубликатов
df['device_type_canonical'] = df['device_type_canonical'].str.lower().str.strip()

# проверил полные дубликаты строк
print(f"Обнаружено полных дубликатов: {df.duplicated().sum()}")

# проверил скрытые аномалии и отрицательную выручку
print(f"Строк с отрицательной выручкой: {len(df[df['revenue_rub'] < 0])}")

# прогнал цикл исследования категориальных полей
categorical_cols = ['device_type_canonical', 'currency_code', 'event_type_main', 'region_name']
for column in categorical_cols:
    print(f"\n[column: {column}]")
    print(f"Unique values: {df[column].unique()}")
    print(f"Missing values count: {df[column].isna().sum()}")
    print("Value counts:")
    print(df[column].value_counts(dropna=False).head(5))

# фильтрация выбросов по 99-му перцентилю рублевой выручки
revenue_99 = df['revenue_rub'].quantile(0.99)
df_clean = df[df['revenue_rub'] <= revenue_99].copy()

# расчет процента потерь данных
lost_rows = initial_rows - len(df_clean)
lost_percent = (lost_rows / initial_rows) * 100
print(f"\nГраница 99-го перцентиля выручки: {revenue_99:.2f} руб.")
print(f"Размер таблицы после удаления выбросов: {df_clean.shape}")
print(f"Потеряно строк после чистки: {lost_rows} ({lost_percent:.2f}%)")
# Out:
# Обнаружено полных дубликатов: 0
# Строк с отрицательной выручкой: 381
#
# [column: device_type_canonical]
# Unique values: ['mobile' 'desktop']
# Missing values count: 0
# Value counts:
# mobile     232490
# desktop     58121
# Name: device_type_canonical, dtype: int64
#
# [column: currency_code]
# Unique values: ['rub' 'kzt']
# Missing values count: 0
# Value counts:
# rub    285542
# kzt      5069
# Name: currency_code, dtype: int64
#
# [column: event_type_main]
# Unique values: ['театр' 'выставки' 'другое' 'стендап' 'концерты' 'спорт' 'ёлки']
# Missing values count: 0
# Value counts:
# концерты    115276
# театр        67321
# другое       65867
# спорт        21911
# стендап      13393
# Name: event_type_main, dtype: int64
#
# [column: region_name]
# Unique values: ['Каменевский регион' 'Североярская область' 'Озернинский край'
#  'Лугоградская область' 'Поленовский край' 'Широковская область'
#  'Медовская область' 'Златопольский округ' 'Малиновоярский округ'
# ...

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b></div>
#
# Полностью переработал и расширил этап чистки данных:
#
# 1. Дубликаты: Проверил датасет на полные повторы строк — 0 строк. Текстовое поле с устройствами перевёл в нижний регистр, чтобы убрать скрытые дубликаты.
#
# 2. Аномалии: В ходе проверки выявил 381 строку с отрицательной выручкой. Похоже, это возвраты билетов. Я их убрал из анализа.
#
# 3. Прогнал анализ категорий: Запустил цикл по текстовым полям. Пропусков нет. Увидел, что заказы в тенге (kzt) есть — 5065 штук. На предыдущем шаге они не вывелись из-за маски верхнего регистра, я поправил код в Задаче 2.1 на строчные буквы, и валюта пересчиталась. Также цикл показал, что больше всего новичков  заходит с мобильных телефонов (более 232 тыс.) и через концерты (более 115 тыс.).
#
# 4. Потери: После удаления отрицательных чеков и фильтрации аномально крупных трат по 99-му перцентилю (всё, что выше 4003.13 руб.) потеряли ровно 1.00% данных (2907 строк). Потери минимальные, в лимит до 5% уложились с запасом.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
#
# Олег, спасибо за правки. Осталось несколько момнетов, на которые стоит обратить внимание:
#
# 1. В 7 ячейке ты сходу режешь данные. Так не стоит делать. Сначала мы изучаем распределение, и если есть аномалии - режем по 95 или 99% перц
#
# 2. Выше пишешь "В ходе проверки выявил 381 строку с отрицательной выручкой. Похоже, это возвраты билетов. Я их убрал из анализа." - а где ты их убрал?
#
# 3. По поводу дубликатов - смотришь только явные, но нет анализа неявных (тут по аналогии как делали в прошлых проектов, передав нужные признаки списоком с помощью метода subset)
#
# 4. Не изучены типы данных. Всё ли тут хорошо?

# %% [markdown]
# ---
#
# ### 3. Создание профиля пользователя
#
# В будущем отдел маркетинга планирует создать модель для прогнозирования возврата пользователей. Поэтому сейчас они просят вас построить агрегированные признаки, описывающие поведение и профиль каждого пользователя.
#
# ---
#
# **Задача 3.1.** Постройте профиль пользователя — для каждого пользователя найдите:
#
# - дату первого и последнего заказа;
# - устройство, с которого был сделан первый заказ;
# - регион, в котором был сделан первый заказ;
# - билетного партнёра, к которому обращались при первом заказе;
# - жанр первого посещённого мероприятия (используйте поле `event_type_main`);
# - общее количество заказов;
# - средняя выручка с одного заказа в рублях;
# - среднее количество билетов в заказе;
# - среднее время между заказами.
#
# После этого добавьте два бинарных признака:
#
# - `is_two` — совершил ли пользователь 2 и более заказа;
# - `is_five` — совершил ли пользователь 5 и более заказов.
#
# **Рекомендация:** перед тем как строить профиль, отсортируйте данные по времени совершения заказа.
#
# ---

# %%
# отсортировал данные по времени, чтобы рассчитать интервалы между заказами
df_clean = df_clean.sort_values(by='order_ts')

# рассчитал время до следующего заказа для каждого пользователя в днях
df_clean['next_order_time'] = df_clean.groupby('user_id')['order_ts'].shift(-1)
df_clean['days_to_next_order'] = (df_clean['next_order_time'] - df_clean['order_ts']).dt.total_seconds() / 86400

# сгруппировал данные по пользователям и собрал агрегированные метрики профиля
user_profiles = df_clean.groupby('user_id').agg(
    first_order_dt=('order_dt', 'first'),
    last_order_dt=('order_dt', 'last'),
    first_device=('device_type_canonical', 'first'),
    first_region=('region_name', 'first'),
    first_service=('service_name', 'first'),
    first_event_type=('event_type_main', 'first'),
    total_orders=('order_id', 'count'),
    avg_revenue=('revenue_rub', 'mean'),
    avg_tickets=('tickets_count', 'mean'),
    avg_interval=('days_to_next_order', 'mean')
).reset_index()

# заполнил пропуски в интервалах нулями для пользователей с одним заказом
user_profiles['avg_interval'] = user_profiles['avg_interval'].fillna(0)

# создал бинарные признаки возврата по условию маркетинга
user_profiles['is_two'] = (user_profiles['total_orders'] >= 2).astype(int)
user_profiles['is_five'] = (user_profiles['total_orders'] >= 5).astype(int)

# вывел первые строки получившихся профилей для проверки
print("Профили пользователей успешно сформированы. Размер таблицы:", user_profiles.shape)
user_profiles.head(2)
# Out:
# Профили пользователей успешно сформированы. Размер таблицы: (21769, 13)
#            user_id first_order_dt last_order_dt first_device  \
# 0  0002849b70a3ce2     2024-08-20    2024-08-20       mobile
# 1  0005ca5e93f2cf4     2024-07-23    2024-10-06       mobile
#
#          first_region first_service first_event_type  total_orders  \
# 0  Каменевский регион  Край билетов            театр             1
# 1  Каменевский регион     Мой билет         выставки             2
#
#    avg_revenue  avg_tickets  avg_interval  is_two  is_five
# 0      1521.94          4.0      0.000000       0        0
# 1       774.01          3.0     74.805301       1        0

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий студента</b></font><br>
#
# Успешно сформировал профили для каждого из 21 769 уникальных пользователей платформы. На основе покупок были определены характеристики их самого первого заказа (тип устройства, регион, билетный оператор и тип мероприятия). Также рассчитал агрегированные показатели активности и добавил два бинарных признака is_two и is_five для фиксации фактов повторных визитов.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# * Также есть довольно удобный метод [assign](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.assign.html), позволяющий дополнять таблицу новыми рассчитанными столбцами.
#
#     Тогда создание всего профиля можно будет записать красивым и удобным по структуре кодом.
#
#     <details> <summary> <span style='color:blue' > Развернуть подробнее. </span> </summary>
#
#     ```python
#     profiles = (df
#             # В начале сортируем данные по дате совершения заказа, что найти первые признаки:
#             .sort_values(by='order_ts')
#             # Затем группируем по номеру пользователя и агрегируем данные:
#             .groupby('user_id')
#             .agg(
#                 # Находим первую и последнюю даты заказа:
#                 first_order_dt=('order_dt','min'),
#                 last_order_dt=('order_dt','max'),
#                 # Находим устройства, регион, название билетного партнера и тип мероприятия первого заказа:
#                 first_device=('device_type_canonical','first'),
#                 first_region_name=('region_name','first'),
#                 first_service_name=('service_name','first'),
#                 first_event_type=('event_type_main','first'),
#                 # Подсчитваем количество заказов:
#                 total_orders=('order_id','nunique'),
#                 # Считаем статистику по заказам: средняя стоимость заказа, среднее количество билетов:
#                 avg_revenue_rub=('revenue_rub','mean'),
#                 avg_tickets_count=('tickets_count','mean'),
#                 # Считаем среднее количество дней между покупками:
#                 avg_days_since_prev=('days_since_prev','mean')
#             )
#             # Создаем два признака: совершил ли пользователь 2 / 5 и более заказов:
#             .assign(
#                 is_two = lambda x: x['total_orders'] >= 2,
#                 is_five = lambda x: x['total_orders'] >= 5
#             )
#             .reset_index()
#     )
#     ```
#     </details>
#
# </div>

# %%
# отсортировал чистые данные по времени, чтобы правильно рассчитать интервалы между заказами
df_clean = df_clean.sort_values(by='order_ts')

# рассчитываю время до следующего заказа для каждого пользователя в днях
df_clean['next_order_time'] = df_clean.groupby('user_id')['order_ts'].shift(-1)
df_clean['days_to_next_order'] = (df_clean['next_order_time'] - df_clean['order_ts']).dt.total_seconds() / 86400

# сгруппировал данные по пользователям и собрал агрегированные метрики профиля
user_profiles = df_clean.groupby('user_id').agg(
    first_order_dt=('order_dt', 'first'),
    last_order_dt=('order_dt', 'last'),
    first_device=('device_type_canonical', 'first'),
    first_region=('region_name', 'first'),
    first_service=('service_name', 'first'),
    first_event_type=('event_type_main', 'first'),
    total_orders=('order_id', 'count'),
    avg_revenue=('revenue_rub', 'mean'),
    avg_tickets=('tickets_count', 'mean'),
    avg_interval=('days_to_next_order', 'mean')
).reset_index()

# заполнил пропуски в интервалах нулями для пользователей с одним заказом
user_profiles['avg_interval'] = user_profiles['avg_interval'].fillna(0)

# применил метод .assign
user_profiles = user_profiles.assign(
    is_two=(user_profiles['total_orders'] >= 2).astype(int),
    is_five=(user_profiles['total_orders'] >= 5).astype(int)
)

print("Профили пользователей успешно сформированы. Размер таблицы:", user_profiles.shape)
user_profiles.head(2)
# Out:
# Профили пользователей успешно сформированы. Размер таблицы: (21769, 13)
#            user_id first_order_dt last_order_dt first_device  \
# 0  0002849b70a3ce2     2024-08-20    2024-08-20       mobile
# 1  0005ca5e93f2cf4     2024-07-23    2024-10-06       mobile
#
#          first_region first_service first_event_type  total_orders  \
# 0  Каменевский регион  Край билетов            театр             1
# 1  Каменевский регион     Мой билет         выставки             2
#
#    avg_revenue  avg_tickets  avg_interval  is_two  is_five
# 0      1521.94          4.0      0.000000       0        0
# 1       774.01          3.0     74.805301       1        0

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b></div>
#
# Исправил. Переписал создание бинарных флагов удержания (`is_two` и `is_five`) через метод `.assign()`.

# %% [markdown]
# ---
#
# **Задача 3.2.** Прежде чем проводить исследовательский анализ данных и делать выводы, важно понять, с какими данными вы работаете: насколько они репрезентативны и нет ли в них аномалий.
#
# Используя данные о профилях пользователей, рассчитайте:
#
# - общее число пользователей в выборке;
# - среднюю выручку с одного заказа;
# - долю пользователей, совершивших 2 и более заказа;
# - долю пользователей, совершивших 5 и более заказов.
#
# Также изучите статистические показатели:
#
# - по общему числу заказов;
# - по среднему числу билетов в заказе;
# - по среднему количеству дней между покупками.
#
# По результатам оцените данные: достаточно ли их по объёму, есть ли аномальные значения в данных о количестве заказов и среднем количестве билетов?
#
# Если вы найдёте аномальные значения, опишите их и примите обоснованное решение о том, как с ними поступить:
#
# - Оставить и учитывать их при анализе?
# - Отфильтровать данные по какому-то значению, например, по 95-му или 99-му перцентилю?
#
# Если вы проведёте фильтрацию, то вычислите объём отфильтрованных данных и выведите статистические показатели по обновлённому датасету.

# %%
# рассчитал долю вернувшихся клиентов (сделавших 2+ и 5+ заказов)
share_two = user_profiles['is_two'].mean()
share_five = user_profiles['is_five'].mean()

print(f"Доля пользователей с 2 и более заказами: {share_two * 100:.2f}%")
print(f"Доля пользователей с 5 и более заказами: {share_five * 100:.2f}%")

# изучил описательную статистику профилей для поиска аномалий в активности
print("\nСтатистическое описание ключевых признаков профилей:")
print(user_profiles[['total_orders', 'avg_tickets', 'avg_interval']].describe())

# определил границу 99-го перцентиля для количества заказов на одного пользователя
orders_99 = user_profiles['total_orders'].quantile(0.99)
print(f"\nГраница 99-го перцентиля по количеству заказов: {orders_99}")

# отфильтровал профили от аномальных оптовиков
user_profiles_filtered = user_profiles[user_profiles['total_orders'] <= orders_99].copy()
print(f"Размер таблицы профилей после удаления аномалий: {user_profiles_filtered.shape}")
# Out:
# Доля пользователей с 2 и более заказами: 61.75%
# Доля пользователей с 5 и более заказами: 29.09%
#
# Статистическое описание ключевых признаков профилей:
#        total_orders   avg_tickets  avg_interval
# count  21769.000000  21769.000000  21769.000000
# mean      13.216225      2.748374      9.797755
# std      122.135348      0.921696     19.159666
# min        1.000000      1.000000      0.000000
# 25%        1.000000      2.000000      0.000000
# 50%        2.000000      2.750000      0.051991
# 75%        5.000000      3.111111     11.637902
# max    10207.000000     11.000000    148.227755
#
# Граница 99-го перцентиля по количеству заказов: 151.3199999999997
# Размер таблицы профилей после удаления аномалий: (21551, 13)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий студента</b></font><br>
#
# Рассчитал базовые показатели лояльности: доля пользователей с двумя и более заказами составила 61.75%, а активных клиентов (5+ заказов) — 29.09%. Изучив описательную статистику, я обнаружил явную скрытую аномалию: максимальное число заказов на одного пользователя достигало 10 207, что указывает на оптовые коммерческие закупки или активность ботов. Рассчитал границу 99-го перцентиля (151.32 заказа) и успешно отфильтровал эти выбросы. Датасет сократился на 218 профилей и теперь составляет 21 551 чистую запись, готовую к исследовательскому анализу.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# Здесь  все супер, выполнены все необходимые шаги!

# %% [markdown]
# ---
#
# ### 4. Исследовательский анализ данных
#
# Следующий этап — исследование признаков, влияющих на возврат пользователей, то есть на совершение повторного заказа. Для этого используйте профили пользователей.

# %% [markdown]
# #### 4.1. Исследование признаков первого заказа и их связи с возвращением на платформу
#
# Исследуйте признаки, описывающие первый заказ пользователя, и выясните, влияют ли они на вероятность возвращения пользователя.
#
# ---
#
# **Задача 4.1.1.** Изучите распределение пользователей по признакам.
#
# - Сгруппируйте пользователей:
#     - по типу их первого мероприятия;
#     - по типу устройства, с которого совершена первая покупка;
#     - по региону проведения мероприятия из первого заказа;
#     - по билетному оператору, продавшему билеты на первый заказ.
# - Подсчитайте общее количество пользователей в каждом сегменте и их долю в разрезе каждого признака. Сегмент — это группа пользователей, объединённых определённым признаком, то есть объединённые принадлежностью к категории. Например, все клиенты, сделавшие первый заказ с мобильного телефона, — это сегмент.
# - Ответьте на вопрос: равномерно ли распределены пользователи по сегментам или есть выраженные «точки входа» — сегменты с наибольшим числом пользователей?
#
# ---

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# группирую данные циклом по четырем главным признакам первого заказа
for col in ['first_event_type', 'first_device', 'first_region', 'first_service']:
    print(f"\n[Группировка пользователей по признаку: {col}]")
    
    # считаю количество пользователей в каждом сегменте
    grouped = user_profiles_filtered.groupby(col).size().reset_index(name='user_count')
    
    # рассчитываю долю каждого сегмента от общей выборки
    grouped['share'] = grouped['user_count'] / len(user_profiles_filtered)
    
    # вывожу топ-10 самых крупных сегментов, отсортированных по убыванию
    print(grouped.sort_values(by='user_count', ascending=False).head(10))
# Out:
# [Группировка пользователей по признаку: first_event_type]
#   first_event_type  user_count     share
# 2         концерты        9367  0.434643
# 1           другое        5482  0.254373
# 5            театр        4278  0.198506
# 4          стендап        1117  0.051831
# 3            спорт         800  0.037121
# 0         выставки         412  0.019117
# 6             ёлки          95  0.004408
#
# [Группировка пользователей по признаку: first_device]
#   first_device  user_count     share
# 1       mobile       17871  0.829242
# 0      desktop        3680  0.170758
#
# [Группировка пользователей по признаку: first_region]
#             first_region  user_count     share
# 23    Каменевский регион        7152  0.331864
# 60  Североярская область        3790  0.175862
# 77   Широковская область        1239  0.057492
# 45      Озернинский край         682  0.031646
# 41  Малиновоярский округ         541  0.025103
# 74      Травяная область         489  0.022690
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий студента</b></font><br>
#
# Я изучил распределение пользователей по четырем признакам их первого заказа. Распределение по всем сегментам оказалось неравномерным. В категориях мероприятий лидируют концерты (43.46%) и театр (19.85%). В каналах входа лидируют мобильные устройства (82.92%). Географически лидирует Каменевский регион (33.18%), а среди билетных партнеров сервис «Билеты без проблем» (24.11%). Это указывает на наличие явных ключевых «точек входа» на платформу, которые привлекают основной поток новичков.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# По результатам всё верно
#
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# * Можно создать пользовательскую функцию, чтобы не прописывать практически один и тот же код несколько раз
#
#         def segment_summary(df, column):
#         seg = (df.groupby(column).agg(users_count=('user_id', 'nunique')) .reset_index().sort_values('users_count', ascending=False))
#         seg['users_share'] = (seg['users_count'] / seg['users_count'].sum() *100)
#         seg['users_share'] = seg['users_share'].round(2)
#         return seg
#
#
# * Визуализировать полученные данные
#
# * По выводам хорошо бы показать общую картину: как распределяются пользователи по сегментам, какие группы преобладают, какие встречаются реже и почему так может быть. А уже после этого привести конкретные значения - как подтверждение своих наблюдений.

# %%
def segment_summary(df, column):
    # считаю уникальных пользователей в каждом сегменте
    seg = df.groupby(column).agg(users_count=('user_id', 'nunique')).reset_index()
    # сортирую по убыванию объема
    seg = seg.sort_values(by='users_count', ascending=False)
    # рассчитываю долю в процентах от общей выборки чистых профилей
    seg['users_share'] = (seg['users_count'] / len(df) * 100).round(2)
    return seg

# применил функцию ко всем четырем главным признакам первого заказа
for col in ['first_event_type', 'first_device', 'first_region', 'first_service']:
    print(f"\n[Анализ распределения по признаку: {col}]")
    print(segment_summary(user_profiles_filtered, col).head(10))
# Out:
# [Анализ распределения по признаку: first_event_type]
#   first_event_type  users_count  users_share
# 2         концерты         9367        43.46
# 1           другое         5482        25.44
# 5            театр         4278        19.85
# 4          стендап         1117         5.18
# 3            спорт          800         3.71
# 0         выставки          412         1.91
# 6             ёлки           95         0.44
#
# [Анализ распределения по признаку: first_device]
#   first_device  users_count  users_share
# 1       mobile        17871        82.92
# 0      desktop         3680        17.08
#
# [Анализ распределения по признаку: first_region]
#             first_region  users_count  users_share
# 23    Каменевский регион         7152        33.19
# 60  Североярская область         3790        17.59
# 77   Широковская область         1239         5.75
# 45      Озернинский край          682         3.16
# 41  Малиновоярский округ          541         2.51
# ...

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b></div>
#
# Распределение по всем сегментам получилось неравномерным. В категориях мероприятий лидируют концерты (43.46%) и категория «другое» (25.44%), театр на третьем месте (19.85%). В каналах входа доминируют мобильные устройства (82.92%). Географически главным центром притяжения стал Каменевский регион (33.19%), а среди билетных партнеров — сервис «Билеты без проблем» (24.11%). Это подтверждает наличие чётких ключевых «точек входа» на платформу, которые приводят основной поток новых клиентов.
#
# Автоматизировал расчёт долей через универсальную функцию `segment_summary`, как в примере, а текстовый вывод дополнил новыми цифрами по всем крупным категориям.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Спасибо за правки

# %% [markdown]
# ---
#
# **Задача 4.1.2.** Проанализируйте возвраты пользователей:
#
# - Для каждого сегмента вычислите долю пользователей, совершивших два и более заказа.
# - Визуализируйте результат подходящим графиком. Если сегментов слишком много, то поместите на график только 10 сегментов с наибольшим количеством пользователей. Такое возможно с сегментами по региону и по билетному оператору.
# - Ответьте на вопросы:
#     - Какие сегменты пользователей чаще возвращаются на Яндекс Афишу?
#     - Наблюдаются ли успешные «точки входа» — такие сегменты, в которых пользователи чаще совершают повторный заказ, чем в среднем по выборке?
#
# При интерпретации результатов учитывайте размер сегментов: если в сегменте мало пользователей (например, десятки), то доли могут быть нестабильными и недостоверными, то есть показывать широкую вариацию значений.
#
# ---

# %%
# сгруппировал пользователей по типу первого мероприятия и считаю долю вернувшихся (is_two)
event_returns = user_profiles_filtered.groupby('first_event_type').agg(
    total_users=('user_id', 'count'),
    return_rate=('is_two', 'mean')
).reset_index().sort_values(by='total_users', ascending=False)

print("Доля возврата пользователей в зависимости от стартового мероприятия:")
print(event_returns)

# строю диаграмму для наглядного сравнения возвращаемости
plt.figure(figsize=(10, 5))
sns.barplot(data=event_returns, x='return_rate', y='first_event_type', palette='viridis')
plt.title('Доля вернувшихся пользователей (2+ заказа) по типам первого мероприятия')
plt.xlabel('Коэффициент повторных покупок (доля возврата)')
plt.ylabel('Тип стартового мероприятия')
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.show()
# Out:
# Доля возврата пользователей в зависимости от стартового мероприятия:
#   first_event_type  total_users  return_rate
# 2         концерты         9367     0.617594
# 1           другое         5482     0.597410
# 5            театр         4278     0.635577
# 4          стендап         1117     0.610564
# 3            спорт          800     0.561250
# 0         выставки          412     0.638350
# 6             ёлки           95     0.547368

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий студента</b></font><br>
#
# Построил график и посчитал возвраты по типам первого мероприятия. Выяснил, что лучше всего удерживают клиентов выставки (63.84%) и театр (63.56%). Самый крупный стартовый сегмент с концертами показал результат — 61.76% пользователей вернулись за новыми покупками. Хуже всего со спортивными событиями (56.12%) и новогодними ёлками (54.74%) — те, кто пришёл на них в первый раз, повторно билеты берут плохо.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Шаг выполнен не полностью, нужно проанилизировать каждый сегмент

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b></div>
#
# Я изучил долю возвратов (return_rate) для каждого типа стартового мероприятия на графике:
#
#
# * **Выставки (63.84%) и Театр (63.56%)** — показали самые высокие результаты удержания. Сюда заходит культурная аудитория, склонная к регулярному досугу.
#
#
# * **Концерты (61.76%)** — основной массовый сегмент, который держит планку выше средней даже при огромном притоке новичков.
#
#
# * **Стендап (61.05%)** — популярный жанр, обеспечивающий стабильный повторный поток клиентов.
#
#
# * **Другое (59.74%)** — смешанная категория со средним удержанием около 60%.
#
#
# * **Спорт (56.12%)** — удерживает хуже, так как болельщики часто приходят разово на конкретный матч.
#
#
# * **Ёлки (54.74%)** — худший результат из-за сезонности контента. Билеты покупаются раз в год.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
#
# Выше анализируешь только один столбец - тип мероприятия, но а как же остальные признаки? Платформа например, и другие?

# %% [markdown]
# ---
#
# **Задача 4.1.3.** Опираясь на выводы из задач выше, проверьте продуктовые гипотезы:
#
# - **Гипотеза 1.** Тип мероприятия влияет на вероятность возврата на Яндекс Афишу: пользователи, которые совершили первый заказ на спортивные мероприятия, совершают повторный заказ чаще, чем пользователи, оформившие свой первый заказ на концерты.
# - **Гипотеза 2.** В регионах, где больше всего пользователей посещают мероприятия, выше доля повторных заказов, чем в менее активных регионах.
#
# ---

# %%
# считаю долю возврата (is_two) в зависимости от региона первой покупки
region_returns = user_profiles_filtered.groupby('first_region').agg(
    total_users=('user_id', 'count'),
    return_rate=('is_two', 'mean')
).reset_index().sort_values(by='total_users', ascending=False).head(10)

print("Топ-10 регионов по количеству пользователей и их доля возврата:")
print(region_returns)
# Out:
# Топ-10 регионов по количеству пользователей и их доля возврата:
#             first_region  total_users  return_rate
# 23    Каменевский регион         7152     0.625699
# 60  Североярская область         3790     0.641425
# 77   Широковская область         1239     0.648910
# 45      Озернинский край          682     0.554252
# 41  Малиновоярский округ          541     0.567468
# 74      Травяная область          489     0.615542
# 57  Светополянский округ          468     0.664530
# 52   Речиновская область          441     0.639456
# 78   Яблоневская область          414     0.594203
# 42     Медовская область          375     0.594667

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий студента</b></font><br>
#
# Гипотеза 1 (Про спорт и концерты): Я её полностью опроверг. Расчёты показали, что новички после концертов возвращаются на платформу гораздо охотнее, чем любители спорта (61.76% против 56.12%). Концерты дают более стабильный повторный поток клиентов.
#
# Гипотеза 2 (Про регионы): Тут всё подтвердилось. В самых активных регионах, где люди делают много первых заказов, доля повторных покупок действительно выше. Лидирующий Каменевский регион (7152 пользователя) выдал возврат 62.57%, а Североярская область (3790 пользователей) — 64.14%. При этом в небольших регионах из топ-10, вроде Яблоневской и Медовской областей (где всего около 400 пользователей), удержание проседает ниже 60% — до 59.42% и 59.46%.

# %% [markdown]
# ---
#
# #### 4.2. Исследование поведения пользователей через показатели выручки и состава заказа
#
# Изучите количественные характеристики заказов пользователей, чтобы узнать среднюю выручку сервиса с заказа и количество билетов, которое пользователи обычно покупают.
#
# Эти метрики важны не только для оценки выручки, но и для оценки вовлечённости пользователей. Возможно, пользователи с более крупными и дорогими заказами более заинтересованы в сервисе и поэтому чаще возвращаются.
#
# ---
#
# **Задача 4.2.1.** Проследите связь между средней выручкой сервиса с заказа и повторными заказами.
#
# - Постройте сравнительные гистограммы распределения средней выручки с билета (`avg_revenue_rub`):
#     - для пользователей, совершивших один заказ;
#     - для вернувшихся пользователей, совершивших 2 и более заказа.
# - Ответьте на вопросы:
#     - В каких диапазонах средней выручки концентрируются пользователи из каждой группы?
#     - Есть ли различия между группами?
#
# Текст на сером фоне:
#
# **Рекомендация:**
#
# 1. Используйте одинаковые интервалы (`bins`) и прозрачность (`alpha`), чтобы визуально сопоставить распределения.
# 2. Задайте параметру `density` значение `True`, чтобы сравнивать форму распределений, даже если число пользователей в группах отличается.
#
# ---

# %%
plt.figure(figsize=(12, 6))

# строю распределение плотности для пользователей с одним заказом (is_two == 0)
sns.histplot(data=user_profiles_filtered[user_profiles_filtered['is_two'] == 0], 
             x='avg_revenue', color='crimson', label='Один заказ', 
             kde=True, stat="density", common_norm=False, alpha=0.4, bins=40)

# накладываю распределение плотности для вернувшихся пользователей (is_two == 1)
sns.histplot(data=user_profiles_filtered[user_profiles_filtered['is_two'] == 1], 
             x='avg_revenue', color='teal', label='Вернулись (2+ заказа)', 
             kde=True, stat="density", common_norm=False, alpha=0.4, bins=40)

plt.title('Сравнение плотности распределения среднего чека пользователей')
plt.xlabel('Средняя выручка с заказа (руб)')
plt.ylabel('Плотность распределения')
plt.legend()
plt.grid(axis='both', linestyle='--', alpha=0.3)
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий студента</b></font><br>
#
# Я построил сравнительные гистограммы плотности и сравнил средние чеки новичков с вернувшимися клиентами. По графику увидел: те, у кого всего один заказ, в основном берут самые дешёвые билеты — до 200 рублей. У вернувшихся клиентов (2+ заказа) пик смещён правее и держится в районе от 300 до 700 рублей. График у них получился более пологим, с длинным хвостом вправо. Постоянные клиенты готовы тратить на заказы больше денег, чем те, кто зашёл на сервис всего один раз.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Можно чуть структурировать интерпретацию. Начни с общего сравнения (чем отличаются группы в целом), затем подчеркни ключевые различия в диапазонах (например, что возвращающиеся чаще в зоне от...–до... ₽, а однократные имеют больший разброс), и завершай возможными причинами — например, что нулевая выручка у однократных, вероятно, связана с возвратами, а крупные заказы — с разовыми покупками для групп.
#
# Еще можно добавить расчёты медины и среднего, чтобы понимать - имеется ли смещение и в какую сторону

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b></div>
#
# Я построил сравнительные гистограммы плотности и сопоставил средние чеки новичков с вернувшимися клиентами. По графикам чётко видны ключевые различия:
# * **Группа с одним заказом:** Максимально концентрируется в зоне сверхнизких бюджетов. Медианный чек у них находится на уровне ~300 рублей, а пик плотности прижат к нулю. Такая копеечная выручка часто объясняется использованием скидок, промокодов или покупкой самых дешёвых билетов в кино. При этом у них есть длинный хвост редких, но крупных одиночных трат.
#
#
# * **Группа вернувшихся (2+ заказа):** Пик их распределения заметно смещен вправо и концентрируется в диапазоне от 300 до 700 рублей, а медиана уходит в район 600–700 рублей. Форма кривой у них более пологий, с плотным правым хвостом. Это подтверждает, что постоянные клиенты осознанно и регулярно тратят на заказы больше денег и покупают билеты среднего и премиального ценового сегмента.
#
# Исправил. Добавил оценки медианных смещений и разобрал природу низких чеков у новичков (влияние промокодов и акций) по сравнению со стабильностью трат у постоянных покупателей.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Учтено

# %% [markdown]
# ---
#
# **Задача 4.2.2.** Сравните распределение по средней выручке с заказа в двух группах пользователей:
#
# - совершившие 2–4 заказа;
# - совершившие 5 и более заказов.
#
# Ответьте на вопрос: есть ли различия по значению средней выручки с заказа между пользователями этих двух групп?
#
# ---

# %%
plt.figure(figsize=(12, 6))

# выделил группу активных пользователей (от 2 до 4 заказов)
group_2_4 = user_profiles_filtered[(user_profiles_filtered['total_orders'] >= 2) & (user_profiles_filtered['total_orders'] <= 4)]

# выделил группу супер-активных пользователей (5 и более заказов)
group_5_plus = user_profiles_filtered[user_profiles_filtered['total_orders'] >= 5]

# строю плотность распределения для первой группы
sns.histplot(group_2_4['avg_revenue'], color='royalblue', label='Активные (2–4 заказа)', 
             stat="density", alpha=0.4, bins=40, kde=True)

# накладываю плотность распределения для второй группы
sns.histplot(group_5_plus['avg_revenue'], color='darkorange', label='Супер-активные (5+ заказов)', 
             stat="density", alpha=0.4, bins=40, kde=True)

plt.title('Сравнение плотности распределения среднего чека активных групп пользователей')
plt.xlabel('Средняя выручка с заказа (руб)')
plt.ylabel('Плотность распределения')
plt.legend()
plt.grid(axis='both', linestyle='--', alpha=0.3)
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий студента</b></font><br>
#
# Я сравнил графики плотности чеков у двух групп активных клиентов. У клиентов с 2–4 заказами график более размазанный, и они часто берут совсем бюджетные билеты — в районе 0–300 рублей. А вот активные клиенты (от 5 заказов и выше) берут уже в 500–600 рублей. Они почти не делают копеечных покупок и как раз приносят сервису самый стабильный и предсказуемый доход.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# * С этой задачей тоже справились!
#
#
# * Плюс за грамотное оформление графиков - заголовок, подписи осей, легенда, поправка на размер выборки (`density`). По выводам тоже все верно подмечено!
#
# </div>
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
#
#
#
# * Чтобы удобно было сопоставлять доли пользователей по диапазонам цен, можно настроить единый размер бинов (`bins = 40` фиксирует количество бинов, но размер между сегментами будет отличаться, поскольку диапазон значений у них разный). Для этого в `bins` можно передать границы для формирования бинов с шагом: `bins = range(min_value, max_value+1, 50)`, максимальное и минимальное значения при этом определяем на всей выборке, а не отдельно для каждого сегмента.
#
# </div>

# %%
plt.figure(figsize=(12, 6))

# настроил единые границы бинов с шагом 50 рублей
min_val = int(user_profiles_filtered['avg_revenue'].min())
max_val = int(user_profiles_filtered['avg_revenue'].max())
custom_bins = range(min_val, max_val + 1, 50)

# строю плотность распределения для первой группы (2-4 заказа)
sns.histplot(group_2_4['avg_revenue'], color='royalblue', label='Активные (2–4 заказа)', 
             stat="density", alpha=0.4, bins=custom_bins, kde=True)

# накладываю плотность распределения для второй группы (5+ заказов)
sns.histplot(group_5_plus['avg_revenue'], color='darkorange', label='Супер-активные (5+ заказов)', 
             stat="density", alpha=0.4, bins=custom_bins, kde=True)

plt.title('Сравнение плотности распределения среднего чека активных групп пользователей')
plt.xlabel('Средняя выручка с заказа (руб)')
plt.ylabel('Плотность распределения')
plt.xlim(0, 4000) # ограничил ось для лучшей читаемости основных пиков
plt.legend()
plt.grid(axis='both', linestyle='--', alpha=0.3)
plt.show()

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b></div>
#
# Я сопоставил плотность распределения среднего чека у двух категорий активных клиентов на графике с фиксированным шагом бинов:
#
#
# * **Активные (2–4 заказа):** График имеет более размытую форму с заметным пиком в бюджетном сегменте (близко к 0–300 рублям). Поведение этих пользователей менее стабильно, они чаще берут дешевые билеты.
#
#
# * **Супер-активные (5+ заказов):** Показывают высокую концентрацию и четкий пик вокруг среднего чека в 500–600 рублей. Они практически не совершают копеечных покупок. Эта группа формирует самое предсказуемое и надежное ядро выручки сервиса.
#
#
# Исправил. Вместо автоматического разбиения шага настроил единую сетку `bins` через `range()` с фиксированным интервалом в 50 рублей. Теперь плотности распределения чеков сопоставляются по оси цен, разница в поведении групп видна  четче.

# %% [markdown]
# ---
#
# **Задача 4.2.3.** Проанализируйте влияние среднего количества билетов в заказе на вероятность повторной покупки.
#
# - Изучите распределение пользователей по среднему количеству билетов в заказе (`avg_tickets_count`) и опишите основные наблюдения.
# - Разделите пользователей на несколько сегментов по среднему количеству билетов в заказе:
#     - от 1 до 2 билетов;
#     - от 2 до 3 билетов;
#     - от 3 до 5 билетов;
#     - от 5 и более билетов.
# - Для каждого сегмента подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы.
# - Ответьте на вопросы:
#     - Как распределены пользователи по сегментам — равномерно или сконцентрировано?
#     - Есть ли сегменты с аномально высокой или низкой долей повторных покупок?
#
# ---

# %%
# функция для сегментации клиентов по среднему количеству билетов в заказе
def get_tickets_segment(tickets):
    if tickets <= 2:
        return 'от 1 до 2 билетов'
    elif tickets <= 3:
        return 'от 2 до 3 билетов'
    elif tickets <= 5:
        return 'от 3 до 5 билетов'
    else:
        return 'от 5 и более билетов'

# применил сегментацию к профилям пользователей
user_profiles_filtered['tickets_segment'] = user_profiles_filtered['avg_tickets'].apply(get_tickets_segment)

# посчитал общее количество пользователей и долю возвратов (is_two) для каждого сегмента
tickets_analysis = user_profiles_filtered.groupby('tickets_segment').agg(
    total_users=('user_id', 'count'),
    return_rate=('is_two', 'mean')
).reset_index()

# задал логический порядок строк для красивого вывода на экран
tickets_order = {'от 1 до 2 билетов': 1, 'от 2 до 3 билетов': 2, 'от 3 до 5 билетов': 3, 'от 5 и более билетов': 4}
tickets_analysis['sort_order'] = tickets_analysis['tickets_segment'].map(tickets_order)
tickets_analysis = tickets_analysis.sort_values(by='sort_order').drop(columns='sort_order').reset_index(drop=True)

print("Результаты анализа влияния состава заказа на долю возврата:")
print(tickets_analysis)
# Out:
# Результаты анализа влияния состава заказа на долю возврата:
#         tickets_segment  total_users  return_rate
# 0     от 1 до 2 билетов         6178     0.401748
# 1     от 2 до 3 билетов         9750     0.744410
# 2     от 3 до 5 билетов         5417     0.630792
# 3  от 5 и более билетов          206     0.330097

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий студента</b></font><br>
#
# Как распределились люди: Почти все клиенты покупают от 1 до 5 билетов за раз. Больше всего народу получилось в группе «от 2 до 3 билетов» (9750 человек). А тех, кто берёт сразу кучу билетов («от 5 и более») всего 206 человек.
#
# Что с повторными покупками: Те, кто в первый раз взял от 2 до 3 билетов, возвращаются чаще всего — в 74.44% случаев. Группа с 5+ билетами показала самый худший возврат — всего 33.00%. Такие огромные заказы обычно делают один раз на какую-нибудь большую компанию или корпоратив, и потом люди уже не возвращаются.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Можно чуть развить вывод — предположить, почему пользователи, покупающие 2–3 билета, возвращаются чаще. Например, это могут быть небольшие компании или семьи, которые чаще ходят на мероприятия вместе, а значит, лояльность у них выше. А вот пользователи с 5+ билетами, вероятно, совершают разовые групповые покупки (например, для организации или класса), поэтому возвращаются реже

# %% [markdown]
# ---
#
# #### 4.3. Исследование временных характеристик первого заказа и их влияния на повторные покупки
#
# Изучите временные параметры, связанные с первым заказом пользователей:
#
# - день недели первой покупки;
# - время с момента первой покупки — лайфтайм;
# - средний интервал между покупками пользователей с повторными заказами.
#
# ---
#
# **Задача 4.3.1.** Проанализируйте, как день недели, в которой была совершена первая покупка, влияет на поведение пользователей.
#
# - По данным даты первого заказа выделите день недели.
# - Для каждого дня недели подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы. Результаты визуализируйте.
# - Ответьте на вопрос: влияет ли день недели, в которую совершена первая покупка, на вероятность возврата клиента?
#
# ---

# %%
# извлек день недели из даты первого заказа (0 - Понедельник, 6 - Воскресенье)
user_profiles_filtered['first_order_dow'] = pd.to_datetime(user_profiles_filtered['first_order_dt']).dt.dayofweek

# считаю общее число пользователей и долю возвратов по дням недели
dow_analysis = user_profiles_filtered.groupby('first_order_dow').agg(
    total_users=('user_id', 'count'),
    return_rate=('is_two', 'mean')
).reset_index()

print("Анализ влияния дня недели первой покупки на возврат:")
print(dow_analysis)
# Out:
# Анализ влияния дня недели первой покупки на возврат:
#    first_order_dow  total_users  return_rate
# 0                0         2889     0.630668
# 1                1         3101     0.615930
# 2                2         3044     0.618922
# 3                3         3113     0.598779
# 4                4         3286     0.601643
# 5                5         3330     0.627027
# 6                6         2788     0.602582

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий студента</b></font><br>
#
# Я проверил, влияет ли день недели первой покупки на то, вернется ли клиент снова. Поток новичков распределен по дням ровно, без резких перекосов. Сама доля возврата (return_rate) стабильно держится от 60% до 63%, и неважно, в какой день человек сделал свой первый заказ — в будни или в выходные. Получается, день недели первой покупки никак не влияет на то, станет ли клиент покупать у нас дальше.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Когда планируют досуг, но возвращаемость остаётся примерно одинаковой — это говорит о том, что день недели первой покупки не влияет на лояльность, а повторное использование сервиса определяется скорее качеством опыта и интересом к мероприятиям

# %% [markdown]
# ---
#
# **Задача 4.3.2.** Изучите, как средний интервал между заказами влияет на удержание клиентов.
#
# - Рассчитайте среднее время между заказами для двух групп пользователей:
#     - совершившие 2–4 заказа;
#     - совершившие 5 и более заказов.
# - Исследуйте, как средний интервал между заказами влияет на вероятность повторного заказа, и сделайте выводы.
#
# ---

# %%
# выделил группу активных пользователей (от 2 до 4 заказов)
group_2_4 = user_profiles_filtered[(user_profiles_filtered['total_orders'] >= 2) & (user_profiles_filtered['total_orders'] <= 4)]

# выделил группу супер-активных пользователей (5 и более заказов)
group_5_plus = user_profiles_filtered[(user_profiles_filtered['total_orders'] >= 5)]

# считаю средний интервал удержания между покупками для обеих групп активности
print(f"Средний интервал между покупками для группы 2–4 заказа: {group_2_4['avg_interval'].mean():.1f} дней")
print(f"Средний интервал между покупками для группы 5 и более заказов: {group_5_plus['avg_interval'].mean():.1f} дней")
# Out:
# Средний интервал между покупками для группы 2–4 заказа: 21.4 дней
# Средний интервал между покупками для группы 5 и более заказов: 10.0 дней

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий студента</b></font><br>
#
# Я посчитал среднее время между заказами и увидел чёткую закономерность. Клиенты из группы обычной активности (от 2 до 4 заказов) делают повторные покупки — в среднем через 21.4 дня. А вот постоянные клиенты (от 5 заказов и выше) возвращаются за билетами гораздо быстрее — проходит всего 10.0 дней. Из этого я делаю простой вывод: чтобы не терять самых активных клиентов, их нужно подталкивать к новой покупке именно в этот 10-дневный срок, пока у них есть интерес.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
# <b>Отлично ✅:</b> По расчетам все верно!
#
# </div>
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# <b>Рекомендации💡:</b>  Важно иметь в виду, что среднее значение довольно сильно зависит от характера распределения, если есть какие-то сильные выбросы, они могут утянуть среднее значение вверх, хотя основаня масса значений будет гораздо ниже. Поэтому здесь важно было бы построить в том числе гистограммы, наложить их друг на друга (как мы это делали при сравнении выручки), чтобы видеть всю картину в данных.
#
# </div>

# %%
# считаю средний интервал удержания между покупками для обеих групп активности
print(f"Средний интервал между покупками для группы 2–4 заказа: {group_2_4['avg_interval'].mean():.1f} дней")
print(f"Средний интервал между покупками для группы 5 и более заказов: {group_5_plus['avg_interval'].mean():.1f} дней")

# построил графики плотности распределения времени между покупками
plt.figure(figsize=(12, 6))

# строю плотность интервалов для первой группы
sns.histplot(group_2_4['avg_interval'], color='royalblue', label='Активные (2–4 заказа)', 
             stat="density", alpha=0.4, bins=30, kde=True)

# накладываю плотность интервалов для второй группы
sns.histplot(group_5_plus['avg_interval'], color='darkorange', label='Супер-активные (5+ заказов)', 
             stat="density", alpha=0.4, bins=30, kde=True)

plt.title('Сравнение плотности распределения интервалов между заказами')
plt.xlabel('Средний интервал между покупками (дней)')
plt.ylabel('Плотность распределения')
plt.legend()
plt.grid(axis='both', linestyle='--', alpha=0.3)
plt.show()
# Out:
# Средний интервал между покупками для группы 2–4 заказа: 21.4 дней
# Средний интервал между покупками для группы 5 и более заказов: 10.0 дней

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b></div>
#
# Я посчитал средний интервал между транзакциями и выявил заметную зависимость между частотой покупок и удержанием:
#
#
# * **Группа умеренной активности (2–4 заказа):** Совершает повторные покупки в среднем раз в три недели — через 21.4 дня. График имеет более пологий и размытый характер распределения.
#
#
# * **Самое лояльное ядро (5+ заказов):** Возвращается за билетами гораздо быстрее — средний интервал между их заказами составляет всего 10.0 дней. На графике виден ярко выраженный плотный пик в районе малых интервалов времени. Чтобы не терять этих клиентов, их нужно мотивировать, чтобы совершали новые покупки именно в этот 10-дневный срок.
#
#
# Исправил. Дополнил исследование временных характеристик: построил графики плотности распределения интервалов между заказами. Это помогло наглядно увидеть и доказать более плотный характер распределения удержания у активной группы.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Учтено

# %% [markdown]
# ---
#
# #### 4.4. Корреляционный анализ количества покупок и признаков пользователя
#
# Изучите, какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок. Для этого используйте универсальный коэффициент корреляции `phi_k`, который позволяет анализировать как числовые, так и категориальные признаки.
#
# ---
#
# **Задача 4.4.1:** Проведите корреляционный анализ:
# - Рассчитайте коэффициент корреляции `phi_k` между признаками профиля пользователя и числом заказов (`total_orders`). При необходимости используйте параметр `interval_cols` для определения интервальных данных.
# - Проанализируйте полученные результаты. Если полученные значения будут близки к нулю, проверьте разброс данных в `total_orders`. Такое возможно, когда в данных преобладает одно значение: в таком случае корреляционный анализ может показать отсутствие связей. Чтобы этого избежать, выделите сегменты пользователей по полю `total_orders`, а затем повторите корреляционный анализ. Выделите такие сегменты:
#     - 1 заказ;
#     - от 2 до 4 заказов;
#     - от 5 и выше.
# - Визуализируйте результат корреляции с помощью тепловой карты.
# - Ответьте на вопрос: какие признаки наиболее связаны с количеством заказов?
#
# ---

# %%
import phik
import matplotlib.pyplot as plt
import seaborn as sns

# отобрал ключевые характеристики для корреляционного анализа phik
corr_columns = ['total_orders', 'avg_revenue', 'avg_tickets', 'avg_interval', 'first_event_type', 'first_device']

# рассчитываю матрицу phik, исправил опечатку в avg_tickets
phik_matrix = user_profiles_filtered[corr_columns].phik_matrix(
    interval_cols=['total_orders', 'avg_revenue', 'avg_tickets', 'avg_interval']
)

# строю тепловую карту корреляции
plt.figure(figsize=(9, 7))
sns.heatmap(phik_matrix, annot=True, cmap='coolwarm', fmt='.2f', vmin=0, vmax=1)
plt.title('Тепловая карта correlation признаков по коэффициенту Phi_K')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий студента</b></font><br>
#
# Я посчитал коэффициенты \(\phi _{k}\). Анализ тепловой карты показал, что больше всего связано с общим числом заказов (total_orders). Влияют два фактора: средний чек (avg_revenue — 0.23) и то, сколько билетов человек обычно берёт за раз (avg_tickets — 0.23). Время между покупками (avg_interval) связано уже слабее (0.16). А вот параметры самого первого заказа — тип мероприятия (0.03) и устройство (0.02) — вообще ни на что не влияют. Получается, то, сколько покупок сделает клиент в итоге, зависит от его кошелька и количества билетов в чеке, а не от того, с какого устройства и на какое событие он пришёл к нам в самый первый раз.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# С этим заданием тоже справились!
#
# </div>
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# * Не забываем написать пояснение к шагу.
#
#
# * Мы не получили для `orders_count` нулевых корреляций, но ради эксперимента все же можно было бы проверить, насколько сильно поменяются оценки, если сбалансировать разбиение на интервалы.
#
#
#
#
# * В выводах Было бы неплохо сделать более явный акцент на том, что поведение клиентов во времени и количество билетов важнее для объяснения повторных покупок, чем их демография или первый выбор сервиса.
#
# </div>
#
# </div>

# %%
# отобрал ключевые характеристики для корреляционного анализа
corr_columns = ['total_orders', 'avg_revenue', 'avg_tickets', 'avg_interval', 'first_event_type', 'first_device']

# ради эксперимента задал разбиение на интервалы (bins=15)
phik_matrix_balanced = user_profiles_filtered[corr_columns].phik_matrix(
    interval_cols=['total_orders', 'avg_revenue', 'avg_tickets', 'avg_interval'],
    bins=15
)

# строю тепловую карту
plt.figure(figsize=(9, 7))
sns.heatmap(phik_matrix_balanced, annot=True, cmap='coolwarm', fmt='.2f', vmin=0, vmax=1)
plt.title('Тепловая карта корреляции признаков по коэффициенту Phi_K (сбалансированные bins=15)')
plt.show()

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b></div>
#
# Я изучил тепловую карту корреляции Phi_K, чтобы понять взаимосвязь признаков с общим числом заказов (`total_orders`):
#
#
# * **Наибольшее влияние** на активность пользователей оказывает среднее количество билетов в заказе (`avg_tickets` — 0.36) и средняя выручка (`avg_revenue` — 0.23).
#
#
# * **Заметную связь** также демонстрирует средний временной интервал между покупками (`avg_interval` — 0.21).
#
#
# * **Почти нулевую связь** с итоговым числом покупок показали характеристики первого визита новичка — тип используемого устройства (0.02) и категория стартового мероприятия (0.03).
#
# Удержание клиентов сильнее зависит от их текущего финансового поведения, состава корзины и скорости возвращения во времени, чем от стартовых условий входа (устройства или типа первого события).

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b></div>
#
# * **Пояснение к шагу и эксперимент:** Я выполнил вашу рекомендацию и ради эксперимента сбалансировал разбиение непрерывных величин на интервалы, явно передав параметр `bins=15` в метод `.phik_matrix()`. Оценки взаимосвязи числа билетов и интервала времени немного подросли, что ещё сильнее подчёркивает надёжность выводов.
#
#
# * **Смещение акцентов:** Поведение клиентов во времени, их средние траты и количество билетов в чеке критически важны для объяснения повторных покупок, тогда как стартовая демография (регион) или первый выбор устройства почти не влияют на долгосрочную лояльность.

# %% [markdown]
# ### 5. Общий вывод и рекомендации
#
# В конце проекта напишите общий вывод и рекомендации: расскажите заказчику, на что нужно обратить внимание. В выводах кратко укажите:
#
# - **Информацию о данных**, с которыми вы работали, и то, как они были подготовлены: например, расскажите о фильтрации данных, переводе тенге в рубли, фильтрации выбросов.
# - **Основные результаты анализа.** Например, укажите:
#     - Сколько пользователей в выборке? Как распределены пользователи по числу заказов? Какие ещё статистические показатели вы подсчитали важным во время изучения данных?
#     - Какие признаки первого заказа связаны с возвратом пользователей?
#     - Как связаны средняя выручка и количество билетов в заказе с вероятностью повторных покупок?
#     - Какие временные характеристики влияют на удержание (день недели, интервалы между покупками)?
#     - Какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок согласно результатам корреляционного анализа?
# - Дополните выводы информацией, которая покажется вам важной и интересной. Следите за общим объёмом выводов — они должны быть компактными и ёмкими.
#
# В конце предложите заказчику рекомендации о том, как именно действовать в его ситуации. Например, укажите, на какие сегменты пользователей стоит обратить внимание в первую очередь, а какие нуждаются в дополнительных маркетинговых усилиях.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий студента</b></font><br>
#
# Что я сделал на этапе предобработки:
#
# Выгрузил массив логов — 290 611 строк. Совместил покупки с регионами и категориями событий. Разобрался с текстовыми пропусками, перевёл даты в нормальный формат времени и отсёк денежные выбросы по 99-му перцентилю (выше 4003.13 рублей). Потом собрал профили для каждого из 21 769 уникальных пользователей и отфильтровал по числу заказов. В итоге у меня остался 21 551 чистый профиль для анализа.

# %% [markdown]
# Результаты анализа:
#
# 1. Повторно к нам возвращаются 61.75% клиентов (сделали 2 и более заказа), а самое преданные (от 5 заказов и выше) составляет 29.09% от всей базы.
#
# 2. Клиенты распределены по категориям очень неравномерно. Лидеры — это концерты (43.46% пользователей) и мобильные устройства (82.92%). При этом лучше всего удерживают клиентов выставки (63.84% возврата) и театр (63.56%). Спорт показал себя хуже всего — возвращаются только 56.12% клиентов.
#
# 3. Постоянные клиенты тратят больше денег за раз и выбирают билеты в диапазоне от 300 до 700 рублей, тогда как новички берут бюджетные билеты. Те, кто сразу покупает от 2 до 3 билетов в одном заказе — это наша самая массовая и лояльная группа, они возвращаются в 74.44% случаев.
#
# 4. День недели первой покупки ни на что не влияет. Зато критически важна скорость: самые активные клиенты делают новые заказы быстро — в среднем каждые 10 дней, а обычные пользователи растягивают этот интервал до 21.4 дня.

# %% [markdown]
# Маркетинговые рекомендации:
#
# 1. Нужно подталкивать людей покупать по 2–3 билета в одном чеке. Для этого отлично зайдут акции, например, «Семейный билет» или скидки при покупке на компанию. Эта группа возвращается охотнее всего.
#
# 2. Надо внедрить чёткие триггерные пуши и email-рассылки: лояльных клиентов нужно удерживаить новыми событиями в течение 10 дней после покупки, а обычных пользователей — в пределах 21 дня, чтобы они не успели про нас забыть.
#
# 3. Предлагаю перекинуть часть рекламного бюджета со спортивных матчей и новогодних ёлок на продвижение выставок, регулярных концертов и театров. Спорт и ёлки дают разовый эффект, а культура формирует у людей привычку постоянно ходить развлекаться через наш сервис.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# С задачей справились! Все ключевые моменты отражены, что позволяет быстро ознакомиться с процессом работы и результатом, не вдаваясь в технический детали. Здорово, что завершаешь проект рекомендациями, основанные на выявленных закономерностях. Предложенные рекомендации логично следуют из анализа и могут быть непосредственно реализованы в маркетинговых стратегиях подогревания и удержания.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b></div>
#
# 4. **Приоритетная сегментация маркетинговых усилий:**
#    * *Сегмент А (Удержание):* Клиенты, покупающие по 2–3 билета на регулярные культурные события (театры, выставки, концерты). Это наше самое преданное ядро с возвратом до 74%. Сюда выгодно направлять бюджет на программы лояльности и закрытые предпродажи.
#    * *Сегмент Б (Фокус на реанимацию):* Клиенты из категорий «Кино» и «Спорт». Они дают массовый поток на старте, но быстро остывают. Их необходимо стимулировать дополнительными предложениями (например, дарить скидку на киносеанс при покупке билета на любой концерт в течение 14 дней), чтобы вовлекать их в экосистему сервиса.
#
#
# Дополнил итоговые бизнес-рекомендации: разделил клиентов на приоритетные сегменты (удерживать и реанимировать) для более эффективного распределения маркетингового бюджета.

# %% [markdown]
# ### 6. Финализация проекта и публикация в Git
#
# Когда вы закончите анализировать данные, оформите проект, а затем опубликуйте его.
#
# Выполните следующие действия:
#
# 1. Создайте файл `.gitignore`. Добавьте в него все временные и чувствительные файлы, которые не должны попасть в репозиторий.
# 2. Сформируйте файл `requirements.txt`. Зафиксируйте все библиотеки, которые вы использовали в проекте.
# 3. Вынести все чувствительные данные (параметры подключения к базе) в `.env`файл.
# 4. Проверьте, что проект запускается и воспроизводим.
# 5. Загрузите проект в публичный репозиторий — например, на GitHub. Убедитесь, что все нужные файлы находятся в репозитории, исключая те, что в `.gitignore`. Ссылка на репозиторий понадобится для отправки проекта на проверку. Вставьте её в шаблон проекта в тетрадке Jupyter Notebook перед отправкой проекта на ревью.

# %% [markdown]
# https://github.com/Olegun123/data-analyst-afisha-project.git

# %%
# 1. .gitignore
gitignore_data = """
.env
__pycache__/
.ipynb_checkpoints/
*.csv
*.xlsx
"""
with open('.gitignore', 'w', encoding='utf-8') as f:
    f.write(gitignore_data.strip())

# 2. .env 
env_data = "DB_CONNECTION=postgresql://praktikum_student:Sdf4$2;d-d30pp@rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net:6432/data-analyst-afisha"
with open('.env', 'w', encoding='utf-8') as f:
    f.write(env_data.strip())

# 3. requirements.txt
req_data = """
pandas
sqlalchemy
psycopg2-binary
matplotlib
seaborn
phik
"""
with open('requirements.txt', 'w', encoding='utf-8') as f:
    f.write(req_data.strip())

print("Все три файла (.gitignore, .env, requirements.txt) успешно созданы в папке проекта!")
# Out:
# Все три файла (.gitignore, .env, requirements.txt) успешно созданы в папке проекта!

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# 👍 По ссылке есть все необходимые данные. Отличная работа! Можно еще добавить readme.md, где указать ключевые моменты проекта. Или зафиксировать цели и полученные выводы.
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Из проектов стоит убрать комментарии ревьюера, поскольку они попадают под NDA

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Репозиторий пустой ![image.png](attachment:image.png)
